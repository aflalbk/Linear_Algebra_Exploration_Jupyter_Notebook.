# %%
import numpy as np 
import torch 
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Affine transformation via matrix application

# %%
v = np.array([3,1])
v
# Out:
# array([3, 1])

# %%
def plot_vectors(vectors, colors=None):
    """
    Plot multiple vectors on a graph.
    
    Parameters:
        vectors (list): List of vectors to plot.
        colors (list): List of colors for each vector (optional).
    """
    plt.figure(figsize=(4, 4))
    
    for i, vector in enumerate(vectors):
        if colors is None:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, label=f'Vector {i+1}')
        else:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, color=colors[i], label=f'Vector {i+1}')
    
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.xlim(-3, 3)
    plt.ylim(-3, 3)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.legend()
    plt.title('Vector Plot')
    plt.show()

# %%
plot_vectors([v],['lightblue'])

# %%
I = np.array ([[1,0],[0,1]]) 
I
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
Iv = np.dot(I,v)
Iv
# Out:
# array([3, 1])

# %%
v == Iv
# Out:
# array([ True,  True])

# %%
plot_vectors([Iv],['b'])

# %%
E = np.array ([[1,0],[0,-1]]) 
E
# Out:
# array([[ 1,  0],
#        [ 0, -1]])

# %%
Ev = np.dot(E,v)
Ev
# Out:
# array([ 3, -1])

# %%
plot_vectors([Iv,Ev],["lightblue",'b'])

# %%
G = np.array ([[1,3],[3,-1]]) 
G
# Out:
# array([[ 1,  3],
#        [ 3, -1]])

# %%
Gv = np.dot(G,v)
Gv
# Out:
# array([6, 8])

# %%
plot_vectors([Iv,Gv],["lightblue",'b'])

# %%
v
# Out:
# array([3, 1])

# %%
np.matrix(v).T
# Out:
# matrix([[3],
#         [1]])

# %%
v2 = np.array([2,1])
v3 = np.array([-3,-1])
v4 = np.array([-1,1])

# %%
V = np.concatenate((np.matrix(v).T,
                   np.matrix(v2).T,
                   np.matrix(v3).T,
                   np.matrix(v4).T),
                  axis = 1)
V
# Out:
# matrix([[ 3,  2, -3, -1],
#         [ 1,  1, -1,  1]])

# %%
A = np.array([[-1,4],[2,-2]])

# %%
AV = np.matmul(A,V)
AV
# Out:
# matrix([[ 1,  2, -1,  5],
#         [ 4,  2, -4, -4]])

# %%
# convert a matrix into a 1-dimensional vector

def vectorfy (mtrx,clmn):
    return np.array(mtrx[:,clmn]).reshape(-1)

# %%
vectorfy(V,0)
# Out:
# array([3, 1])

# %%
vectorfy(V,0) == v
# Out:
# array([ True,  True])

# %%
def plot_vectors(vectors, colors=None):
    """
    Plot multiple vectors on a graph.
    
    Parameters:
        vectors (list): List of vectors to plot.
        colors (list): List of colors for each vector (optional).
    """
    plt.figure(figsize=(4, 4))
    
    for i, vector in enumerate(vectors):
        if colors is None:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, label=f'Vector {i+1}')
        else:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, color=colors[i], label=f'Vector {i+1}')
    
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.xlim(-5, 10)
    plt.ylim(-5, 5)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.legend()
    plt.title('Vector Plot')
    plt.show()

# %%
plot_vectors([vectorfy(V,0),vectorfy(V,1),vectorfy(V,2),vectorfy(V,3),
              vectorfy(AV,0),vectorfy(AV,1),vectorfy(AV,2),vectorfy(AV,3)],
             ['b','r','g','y',
             'lightblue','pink','lightgreen','brown'])

# %% [markdown]
# ### Eigenvectors and Eigenvalues

# %%
A
# Out:
# array([[-1,  4],
#        [ 2, -2]])

# %%
lamdah, V=np.linalg.eig(A)

# %%
V
# Out:
# array([[ 0.86011126, -0.76454754],
#        [ 0.51010647,  0.64456735]])

# %%
lamdah
# Out:
# array([ 1.37228132, -4.37228132])

# %%
v1 = V[:,0]
v1
# Out:
# array([0.86011126, 0.51010647])

# %%
v2 = V[:,1]
v2
# Out:
# array([-0.76454754,  0.64456735])

# %% [markdown]
#     lets confirm A*v = lamdah*v

# %%
Av1 = np.dot(A,v1)
Av1
# Out:
# array([1.18031462, 0.70000958])

# %%
lamdah[0] * v1
# Out:
# array([1.18031462, 0.70000958])

# %%
def plot_vectors(vectors, colors=None):
    """
    Plot multiple vectors on a graph.
    
    Parameters:
        vectors (list): List of vectors to plot.
        colors (list): List of colors for each vector (optional).
    """
    plt.figure(figsize=(4, 4))
    
    for i, vector in enumerate(vectors):
        if colors is None:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, label=f'Vector {i+1}')
        else:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, color=colors[i], label=f'Vector {i+1}')
    
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.xlim(-1, 2)
    plt.ylim(-1, 2)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.legend()
    plt.title('Vector Plot')
    plt.show()

# %%
plot_vectors([Av1,v1],['lightblue','blue'])

# %%
np.dot(A,v2) == lamdah[1] * v2
# Out:
# array([ True,  True])

# %%
lamdah[1] * v2
# Out:
# array([ 3.34281692, -2.81822977])

# %%
Av2 = np.dot(A,v2)
Av2
# Out:
# array([ 3.34281692, -2.81822977])

# %%
def plot_vectors(vectors, colors=None, xlim=None, ylim=None):
    """
    Plot multiple vectors on a graph.

    Parameters:
        vectors (list): List of vectors to plot.
        colors (list): List of colors for each vector (optional).
        xlim (tuple): Tuple containing (xmin, xmax) for x-axis limits.
        ylim (tuple): Tuple containing (ymin, ymax) for y-axis limits.
    """
    plt.figure(figsize=(4, 4))
    
    for i, vector in enumerate(vectors):
        if colors is None:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, label=f'Vector {i+1}')
        else:
            plt.quiver(0, 0, vector[0], vector[1], angles='xy', scale_units='xy', scale=1, color=colors[i], label=f'Vector {i+1}')
    
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    
    if xlim is not None:
        plt.xlim(xlim)
    if ylim is not None:
        plt.ylim(ylim)
    
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.legend()
    plt.title('Vector Plot')
    plt.show()

# %%
plot_vectors([Av2,v2,Av1,v1],['lightgreen','green','lightblue','blue'],xlim=(-2,5),ylim=(-5,2))

# %% [markdown]
# #### in 3D

# %%
X = np.array([[25,2,9],[5,26,-5],[3,7,-1]])
X
# Out:
# array([[25,  2,  9],
#        [ 5, 26, -5],
#        [ 3,  7, -1]])

# %%
lamdas_X, V_X = np.linalg.eig(X)
V_X
# Out:
# array([[-0.71175736, -0.6501921 , -0.34220476],
#        [-0.66652125,  0.74464056,  0.23789717],
#        [-0.22170001,  0.15086635,  0.90901091]])

# %%
lamdas_X
# Out:
# array([29.67623202, 20.62117365, -0.29740567])

# %%
v1 = V_X[:,0]
v1
# Out:
# array([-0.71175736, -0.66652125, -0.22170001])

# %%
Xv1 = np.dot(X,V_X[:,0])
Xv1
# Out:
# array([-21.12227645, -19.77983919,  -6.5792208 ])

# %%
lamdas_X[0] * v1
# Out:
# array([-21.12227645, -19.77983919,  -6.5792208 ])

# %%
plot_vectors([v1,Xv1],['blue','lightblue'],xlim=(-25,1),ylim=(-25,2))

# %%
v2 = V_X[:,1]
Xv2 = np.dot(X,V_X[:,1])
plot_vectors([v1,Xv1,v2,Xv2],['blue','lightblue','green','lightgreen'],xlim=(-25,10),ylim=(-25,35))

# %%
v3 = V_X[:,2]
Xv3 = np.dot(X,V_X[:,2])
plot_vectors([Xv1,v1,Xv2,v2,Xv3,v3],['blue','lightblue','green','lightgreen','red','black'],xlim=(-25,10),ylim=(-25,35))
